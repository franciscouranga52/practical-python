# %% [markdown]
# ## Homework for Week 2
#
# The goal for this homework is to see the relevant journalistic uses for what we learned in class in week 1.
#
#
# 1. Making numbers more readable (using f-string literal formatting)
# 2. Organizing data points after acquiring them through scraping (creating lists, dictionaries and lists of dictionaries)
# 3. Extracting data from lists
# 4. Knowing what type of data (or Python object) we have.
# 5. Knowing how many such data points we have.
# 6. Confirming that we have unique values (or removing duplicates in a data set)
# 7. Allowing us to slow down how fast our code runs to avoid detection or being blocked when we start scraping websites!

# %% [markdown]
# ## Working with Numbers

# %% [markdown]
# ### Question 1
#
# Create a variable called ```ppp_loans``` (Paycheck Protection Plan loans) equal to 45.3 million
#
# Print a statement that says "Paycheck Protection Plan loans that totalled (number provided here) in 2021" using f-string literal (0 decimal places)
#
# To be clear, you **must** to use f-string literals and the variable ```ppp_loans``` and **NOT** just typing out the sentence above.

# %%
### answer question 1 here (create more cells if necessary)
ppp_loans = 45_300_000

# %%
print(f"Paycheck Protection Plan loans that totalled: ${ppp_loans:_.0F}")
# Out:
# Paycheck Protection Plan loans that totalled: $45_300_000

# %% [markdown]
# ### Question 2
#
# A teacher earned $45,000 in 1973. Print the value of 45,000 in 2021 dollars to 2 decimal places with thousands separators.
#
# Print a statement that says "A teacher's salary of **whatever_amount** in 1973 is equal to **updated_variable_here** in 2021."
#
# Again, do this programmatically by creating varibles and doing calculations. **Do not** just use cells as a calculator.

# %%
### answer question 2 here (create more cells if necessary)
# CPI between July 1973 and July 2023: 590.05%
tearnings_1973 = 45_000
CPI_1973_2023 = 590.05

# %%
tearnings_2023 = tearnings_1973 * (1+CPI_1973_2023/100)
tearnings_2023
# Out:
# 310522.49999999994

# %%
print(f"Teacher earnings in 2023: ${tearnings_2023:,.2F}")
# Out:
# Teacher earnings in 2023: $310,522.50

# %% [markdown]
# ## Working with Lists

# %% [markdown]
# ### Question 3
#
# You've <a href="https://apps.health.ny.gov/pubdoh/professionals/doctors/conduct/factions/AllRecordsAction.action?">scraped thousands of documents</a> that contain disciplinary actions against doctors in New York state. You compile key words and phrases that will target certain types of violations. These include:
#
# - improper touching
# - self-medication
# - self-prescribing
# - opioid addiction
# - harassment
# - coercion
# - sexual harrassment
# - sex
# - sexual favor
# - abuse of trust
# - opioid prescriptions in return for sex
#
# Create a list that holds the search terms above.

# %%
### answer question 3 here (create more cells if necessary)
violations = ["improper touching",
    "self-medication",
    "self-prescribing",
    "opioid addiction",
    "harassment",
    "coercion",
    "sexual harrassment",
    "sex",
    "sexual favor",
    "abuse of trust",
    "opioid prescriptions in return for sex"]

# %%
violations
# Out:
# ['improper touching',
#  'self-medication',
#  'self-prescribing',
#  'opioid addiction',
#  'harassment',
#  'coercion',
#  'sexual harrassment',
#  'sex',
#  'sexual favor',
#  'abuse of trust',
#  'opioid prescriptions in return for sex']

# %% [markdown]
# ### Question 4
#
# Confirm that you have a list.

# %%
### answer question 4 here (create more cells if necessary)
type(violations)
# Out:
# list

# %% [markdown]
# ### Question 5
#
# How long is this list?

# %%
### answer question 5 here (create more cells if necessary)
len(violations)
# Out:
# 11

# %% [markdown]
# ## Slicing Lists

# %% [markdown]
# ### Question 6
# Combine the two lists into a single list called ```combined_list```

# %%
## combine here
terms_1 = ["Bankruptcy", "Mergers", "Acquisitions", "Private equity", "Bonds"]
terms_2 = ["Short selling", "Liquidations", "Equity", "Inflation", "Markets", "Interest rates"]
combined_list = terms_1 + terms_2

# %% [markdown]
# ### Question 7

# %%
## call combined_list here
combined_list
# Out:
# ['Bankruptcy',
#  'Mergers',
#  'Acquisitions',
#  'Private equity',
#  'Bonds',
#  'Short selling',
#  'Liquidations',
#  'Equity',
#  'Inflation',
#  'Markets',
#  'Interest rates']

# %% [markdown]
# ### Question 8

# %%
## Slice items 1 and 2 from the combined list### Question 7
[combined_list[0], combined_list [1]]
# Out:
# ['Bankruptcy', 'Mergers']

# %% [markdown]
# ### Question 9

# %%
## Slice the 9 and 10 from the combined list### Question 7
[combined_list[8],combined_list[9]]
# Out:
# ['Inflation', 'Markets']

# %% [markdown]
# ## Working with List of Dictionaries

# %% [markdown]
# ### Question 10
#
# #### Create a list of dictionaries called "donations" using the content from the image below:
#
# ![Link to spreadsheet image](data:image/png;base64,...)
#
# You may copy and paste the content from this <a href="https://docs.google.com/spreadsheets/d/1WVWEJDsGs8Phj2qyoCvTqb7U9VNY7fWB/edit?usp=sharing&ouid=109693387539767849007&rtpof=true&sd=true" target="blank">Excel file</a>, but you must manually build the dictionaries.

# %%
### answer question 10 here (create more cells if necessary)
donor1 = {"year":2017,"donor":"David H Koch", "grantee": "Charitable Foundation","amount":15_000_000}
donor2 = {"year":2013,"donor":"Bradley Impact Fund Inc", "grantee": "Young Americas Foundation","amount":11_000}
donor3 = {"year":2016,"donor":"Mercer Family Foundation", "grantee": "The Becket Fund","amount":250_000}
donor4 = {"year":2012,"donor":"Charles Koch Foundation", "grantee": "The Phillips Foundation","amount":25_000}
donor5 = {"year":2017,"donor":"Barbara And Barre Seid Foundation", "grantee": "Boys Scouts of America","amount":2_634_000}

# %%
donors = [donor1, donor2, donor3, donor4, donor5]
donors
# Out:
# [{'year': 2017,
#   'donor': 'David H Koch',
#   'grantee': 'Charitable Foundation',
#   'amount': 15000000},
#  {'year': 2013,
#   'donor': 'Bradley Impact Fund Inc',
#   'grantee': 'Young Americas Foundation',
#   'amount': 11000},
#  {'year': 2016,
#   'donor': 'Mercer Family Foundation',
#   'grantee': 'The Becket Fund',
#   'amount': 250000},
#  {'year': 2012,
#   'donor': 'Charles Koch Foundation',
#   'grantee': 'The Phillips Foundation',
#   'amount': 25000},
#  {'year': 2017,
#   'donor': 'Barbara And Barre Seid Foundation',
#   'grantee': 'Boys Scouts of America',
#   'amount': 2634000}]

# %% [markdown]
# ### Question 11
#
# How many dictionaries are in this list?
# Don't just manually count them.
# There will come a time when you will have thousands of items!

# %%
### answer question 11 here (create more cells if necessary)
len(donors)
# Out:
# 5

# %% [markdown]
# ## Deduplicating content
#
# **Background:** I have provided you below with a list of Small Business Administration Disaster codes associated with each SBA disaster loan that was disbursed between 2010-2018.
#
# There are many duplicates because the SBA gave out loans to many businesses hit by the same disasters. We don't know what these codes stand for.
#
# We need to remove all the duplicates to prepare for an **automated webscrape** to retrieve the descriptions of these codes.

# %%
## Run this cell to register this list
all_disaster_loans_codes = ['FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 'FL-00133', 
 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'AZ-00039', 'NJ-00038', 'NJ-00038', 'NJ-00038', 'HI-00032', 'HI-00032', 'HI-00032', 'HI-00032', 'HI-00032', 'HI-00032', 'NV-00031', 'NV-00031', 'NV-00031', 'KY-00053', 'KY-00053', 'KY-00053', 'KY-00053', 'KY-00053', 'KY-00053', 'KY-00053', 'KY-00053', 'KY-00053', 'KY-00053', 'KY-00053', 'KY-00053', 'KY-00053', 'KY-00053', 'KY-00053', 'KY-00053', 'KY-00053', 'CA-00222', 'CA-00222', 'CA-00222', 'CA-00222', 'CA-00222', 'CA-00222', 'CA-00222', 'CA-00222', 'CA-00222', 'CA-00222', 'CA-00222', 'CA-00222', 'CA-00222', 'CA-00222', 'CA-00222', 'CA-00222', 'CA-00222', 'CA-00222', 'CA-00222', 'CA-00222', 'CA-00222', 'CA-00222', 'UT-00034', 'LA-00053', 'LA-00053', 'LA-00053', 'LA-00053', 'LA-00053', 'LA-00053', 'NY-00151', 'NY-00151', 'NY-00151', 'NY-00151', 'NY-00151', 'NY-00151', 'NY-00151', 'NY-00151', 'NY-00151', 'NY-00151', 'NY-00151', 'NY-00151', 'NY-00151', 'NY-00151', 'NY-00151', 'NY-00151', 'NY-00151', 'NY-00151', 'NY-00151', 'NY-00151', 'NY-00151', 'NY-00151', 'NY-00151', 'NY-00151', 'CA-00227', 'CA-00227', 'CA-00227', 'CA-00227', 'CA-00227', 'CA-00227', 'CA-00227', 'CA-00227', 'CA-00227', 'CA-00227', 'CA-00227', 'CA-00227', 'CA-00227', 'CA-00227', 'CA-00227', 'CA-00227', 'CA-00227', 'CA-00227', 'CA-00227', 'CA-00228', 'CA-00228', 'CA-00228', 'CA-00228', 'CA-00228', 'CA-00228', 'MS-00075', 'MS-00075', 'WA-00052', 'WA-00052', 'WA-00052', 'CA-00231', 'CA-00233', 'CA-00233', 'RI-00013', 'OK-00091', 'OK-00091', 'OK-00091', 'OK-00091', 'OK-00091', 'OK-00091', 'OK-00091', 'OK-00091', 'OK-00091', 'OK-00091', 'OK-00091', 'OK-00091', 'OK-00091', 'OK-00091', 'NY-00158', 'NY-00159', 'VA-00056', 'VA-00056', 'VA-00056', 'VA-00056', 'VA-00056', 'VA-00056', 'VA-00056', 'VA-00056', 'VA-00056', 'VA-00056', 'VA-00056', 'VA-00056', 'VA-00056', 'VA-00056', 'VA-00056', 'FM-00003', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'KY-00054', 'FL-00105', 'FL-00105', 'AL-00057', 'AL-00057', 'AL-00057', 'AL-00057', 'AL-00057', 'AL-00057', 'AL-00057', 'AL-00057', 'AL-00057', 'AL-00057', 'AL-00057', 'AL-00057', 'AL-00057', 'AL-00057', 'AL-00057', 'NE-00064', 'NE-00064', 'NE-00064', 'NE-00064', 'NE-00064', 'NE-00064', 'NE-00064', 'NE-00064', 'NE-00064', 'NE-00064', 'NE-00064', 'NE-00064', 'NE-00064', 'NE-00064', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'OK-00092', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'TX-00447', 'WV-00036', 'WV-00036', 'WV-00036', 'WV-00036', 'WV-00036', 'WV-00036', 'WV-00036', 'WV-00036', 'WV-00036', 'WV-00036', 'WV-00036', 'IL-00045', 'IL-00045', 'IL-00045', 'IL-00045', 'IL-00045', 'MA-00065', 'MA-00065', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'AR-00077', 'WY-00028', 'WY-00028', 'WY-00028', 'KY-00056', 'KY-00056', 'LA-00054', 'LA-00054', 'LA-00054', 'LA-00054', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'MP-00005', 'SD-00067', 'SD-00067', 'SD-00067', 'SD-00067', 'SD-00067', 'SD-00067', 'SD-00067', 'SD-00067', 'SD-00067', 'SD-00067', 'SD-00067', 'SD-00067', 'SD-00067', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'KY-00058', 'MO-00075', 'MO-00075', 'MO-00075', 'MO-00075', 'MO-00075', 'MO-00075', 'MO-00075', 'MO-00075', 'MO-00075', 'MO-00075', 'MO-00075', 'MO-00075', 'MO-00075', 'MO-00075', 'MO-00075', 'MO-00075', 'IN-00055', 'IN-00055', 'IN-00055', 'IN-00055', 'IN-00055', 'IN-00055', 'IN-00055', 'IN-00055', 'IN-00055', 'IN-00055', 'IN-00055', 'IN-00055', 'IN-00055', 'IN-00055', 'IN-00055', 'IN-00055', 'IN-00055', 'IN-00055', 'IN-00055', 'IN-00055', 'IN-00055', 'IN-00055', 'VA-00057', 'VA-00057', 'VA-00057', 'VA-00057', 'NY-00162', 'NY-00162', 'NY-00162', 'NY-00162', 'AK-00031', 'IL-00046', 'IL-00046', 'IL-00046', 'IL-00046', 'CA-00237', 'CA-00237', 'SC-00028', 'SC-00028', 'SC-00028', 'SC-00028', 'SC-00028', 'SC-00028', 'SC-00028', 'SC-00028', 'CO-00073', 'CO-00073', 'CO-00073', 'CO-00073', 'CO-00073', 'CO-00073', 'CA-00238', 'CA-00238', 'CA-00238', 'CA-00238', 'CA-00238', 'CA-00238', 'CA-00238', 'CA-00238', 'CA-00238', 'CA-00238', 'CA-00238', 'CA-00238', 'CA-00238', 'CA-00238', 'CA-00238', 'CA-00238', 'CA-00238', 'CA-00238', 'FL-00107', 'FL-00107', 'FL-00107', 'FL-00107', 'FL-00107', 'FL-00107', 'FL-00107', 'FL-00107', 'FL-00107', 'FL-00107', 'FL-00107', 'FL-00107', 'FL-00107']

# %% [markdown]
# ## Question 12
#
#
#
#
#
# How many values are in this list?

# %%
### answer question 12 here (create more cells if necessary)
len(all_disaster_loans_codes)
# Out:
# 35334

# %% [markdown]
# ## Question 13
#
# Create a **list of unique values** (remove all the duplicates) from the list below.

# %%
### answer question 13 here (create more cells if necessary)
disaster_loans_unique_codes = set(all_disaster_loans_codes)

# %% [markdown]
# ## Question 14
#
# Confirm you have deduplicated the list by counting the number of values.

# %%
### answer question 14 here (create more cells if necessary)
len(disaster_loans_unique_codes)
# Out:
# 684

# %% [markdown]
# ## 15. Counter
# * Build a counter that counts from 2 to 10, but only even numbers.
# * Print the counter numbers in statement that reads: "The even number is [whatever the even number is]".
# * Once it reaches 10, it should print "Done counting from 2 to 10 even numbers!"
# * Pause the numbers for between 12 and 24 seconds inclusive between printing.

# %%
# import randint necessary library
from random import randint 
# import time library
import time

# %%
## build here:
counter = 0
while counter < 10:
    snoozer = randint(12,24)
    time.sleep(snoozer)
    counter = counter + 2
    print(f"The even number is: {counter}") 
print(f"Done counting from 2 to 10 even numbers!")
# Out:
# The even number is: 2
# The even number is: 4
# The even number is: 6
# The even number is: 8
# The even number is: 10
# Done counting from 2 to 10 even numbers!

# %% [markdown]
# ## Congratulations!
#
# You just harnessed the power of Python to accomplish the following tasks that are critical foundational skills to become an advanced data journalist:
#
# 1. Making numbers more readable (using f-string literal formatting)
# 2. Organizing data points after acquiring them through scraping (creating lists, dictionaries and lists of dictionaries)
# 3. Extracting data from lists
# 4. Knowing what type of data (or Python object) we have.
# 5. Knowing how many such data points we have.
# 6. Confirming that we have unique values (or removing duplicates in a data set)
# 7. Allowing us to slow down how fast our code runs to avoid detection or being blocked when we start scraping websites!
