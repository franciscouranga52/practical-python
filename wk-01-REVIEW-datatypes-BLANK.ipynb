# %% [markdown]
# # Week 1 - Review
# ## Python Datatypes
#
# Today's goal is to connect Python to relevant and important data journalism needs.
#
# 1. Making numbers more readable (using f-string literal formatting)
# 2. Organizing data points after acquiring them through scraping (creating lists, dictionaries and lists of dictionaries)
# 3. Knowing what type of data (or Python object) we have.
# 4. Knowing how many such data points we have.
# 5. Confirming that we have unique values (or removing duplicates in a data set)

# %% [markdown]
# ## Python at its most basic

# %% [markdown]
# Here's a scenario:
# - Alfred's monthly share of the rent is ```$1,000```
# - Maggie's share is ```$750```
# - Fatima's is ```$1,200```
#
# What is the total rent per month?

# %%
## you could do this:
alfred_rent = 1000
maggie_rent = 750
fatima_rent = 1200
total_rent = alfred_rent + maggie_rent + fatima_rent
total_rent
# Out:
# 2950

# %%
## you can't do this:

# %% [markdown]
# Thousands separators in data journalism are important
# mainly to avoid human error as we write and read numbers.

# %%
## write numbers with Pythonic thousands separators:

# %%
## what type of data is result?

# %% [markdown]
# What is Alfred and Fatima's combined share of the annual rent?

# %% [markdown]
# The real point of all these calcuations is to underscore how confusing all these numbers are getting...
#
# If there were more roommates or more complex calculations, this could get very confusing. What are these numbers? What do they represent?
#
# We get around this confusion by using variables.

# %%
## Let's assign some variables:

# %%
## what type of data is rent_monthly_alfred?

# %% [markdown]
# ## Variables
#
# Variables are placeholders for values. They can be any of the following:
#
# -   **Numbers**
# -   **Strings**, that are made up of letter, words, sentences, etc.
# -   **Placeholders**, that receive their value from inputs, computations or concatenation of other variables.
# -   **Lists**, that holds a multiple values in one variable.
# -   **Dictionaries**, variables that hold interrelated data or info as key-value pairs)
# -   **Functions**, bits of code that you can reuse...(more on this at some point this semester!).
#
# ...and many many other types of data.

# %% [markdown]
# ### Naming Variables
#
# The idea is to give meaningful names so you aren't confused by what they stand for. Apart from that, here are some basic rules:
#
# -   They ARE case sensitive.
# -   Cannot begin with numbers.
# -   Make them unique (just like IDs, you should only have ONE variable with a particular name).
# -   No spaces between words, but don't use compound words (```monthlyexpensessandeep```) because they are hard to read. Instead use:
#     - hyphens (```monthly-expenses-sandeep```)
#     - camelCase (```monthlyExpensesSandeep```)
#     - **underscores or snake_case: (```monthly_expenses_sandeep```)**
#
#
# -   Don't use any Python programming terms [reserved words](https://betterprogramming.pub/all-33-reserved-keywords-in-python-98e55f6c8ded).
# -   Think of code as story. Each variable is like a character/actor. Naming each in a relevant way such makes the narrative (the code) easier to follow.
# -   Keep the variables short but make sure they make sense.

# %%
## Calculate total monthly rent here based on variables

# %%
## call total monthly rent

# %%
## What is Maggie's share of the total rent?

# %%
## maybe we want to hold on to that value
total_expenses = 1_000_000_000.234567
total_expenses
# Out:
# 1000000000.234567

# %% [markdown]
# ## Print()

# %%
## print total monthly rent
print(f"This is my total monthly expenses: ${total_expenses * 2:_.2F}")
# Out:
# This is my total monthly expenses: $2_000_000_000.47

# %% [markdown]
# # f-string literals

# %% [markdown]
# ## f-string literals to clarify
# ```print(f"Some identifier words: {actual_variable}")```

# %%
## print total all the monthly rents plus totals using f-strings

# %% [markdown]
# ## f-string literals to calculate
#
# ```print(f"total of 2 variables: {(variable_1 + variable_2}")```
#
# **The calculation is NOT retained in memory as a new variable**

# %%
## print out Fatima's share directly in the f-string

# %% [markdown]
# ## f-string literals formatting to prettify

# %%
## add thousands separators

# %%
## round

# %%
## example with big number
big_number = 2_000_163_451.8306490456

# %%
## print big number with and without formatting

# %% [markdown]
# ## Lists
#
# Lists are the most widely used data containers in Python.
#
# Let's build a quick and simple list:

# %%
## list of animals (strings)

# %%
## call your list

# %%
## check the type

# %% [markdown]
# ## Lists
#
# Lists are the most widely used data containers in Python.
#
# - Wrap your data in square brackets ```[]``` to create a list.
# - A list can hold almost everything in Python:
#     - numbers
#     - strings
#     - other lists
#     - dictionaries (more on this today)
#     - booleans (more on this at some point)
#     - functions (a basic intro later this semester)
#     - much more and all of the above at the same time.

# %%
## build a list with strings and numbers (contrived)
mixed_list = ["dog", 2, "pig",["frong", "bird"], "rat", "hen", True, False]

# %%
## call your mixed_list
mixed_list
# Out:
# ['dog', 2, 'pig', ['frong', 'bird'], 'rat', 'hen', True, False]

# %%
## Lists are mutable (as you can add, remove or change items):
mixed_list.append("Sandeep")
mixed_list
# Out:
# ['dog', 2, 'pig', ['frong', 'bird'], 'rat', 'hen', True, False, 'Sandeep']

# %%
mixed_list.append(animals)

# %%
mixed_list
# Out:
# ['dog',
#  2,
#  'pig',
#  ['frong', 'bird'],
#  'rat',
#  'hen',
#  True,
#  False,
#  'Sandeep',
#  ['dog', 'cat', 'pig', 'rat', 'hen']]

# %% [markdown]
# ## List Slicing
#
# Extracting or gathering values from a list

# %%
#### run this list to complete exercises:


toxic_chemicals = [
    "Polyvinyl Chloride",
    "PVC",
    "Perfluorooctanoic Acid",
    "PFOA",
    "Triclosan",
    "Bisphenol-A",
    "BPA",
    "Formaldehyde",
    "Naphthalene",
    "Asbestos"
]

# %%
### call the entire list
toxic_chemicals
# Out:
# ['Polyvinyl Chloride',
#  'PVC',
#  'Perfluorooctanoic Acid',
#  'PFOA',
#  'Triclosan',
#  'Bisphenol-A',
#  'BPA',
#  'Formaldehyde',
#  'Naphthalene',
#  'Asbestos']

# %%
## print the list
print(toxic_chemicals)
# Out:
# ['Polyvinyl Chloride', 'PVC', 'Perfluorooctanoic Acid', 'PFOA', 'Triclosan', 'Bisphenol-A', 'BPA', 'Formaldehyde', 'Naphthalene', 'Asbestos']

# %%
## What is the index position of "Perfluorooctanoic Acid":
toxic_chemicals.index("Perfluorooctanoic Acid")
# Out:
# 2

# %% [markdown]
# #### Now we want to retrieve the data, not the index
#
# ```list_name[index_position]```

# %%
toxic_chemicals[2]
# Out:
# 'Perfluorooctanoic Acid'

# %%
### call the first item in the list above
toxic_chemicals[0]
# Out:
# 'Polyvinyl Chloride'

# %%
### call the 2nd and 3rd items in the list above
[toxic_chemicals[1], toxic_chemicals[3]]
# Out:
# ['PVC', 'PFOA']

# %%
toxic_chemicals[1:3]
# Out:
# ['PVC', 'Perfluorooctanoic Acid']

# %%
### call the last item in the list
toxic_chemicals[-1]
# Out:
# 'Asbestos'

# %%
### call the last 3 items in the list
toxic_chemicals[-3:]
# Out:
# ['Formaldehyde', 'Naphthalene', 'Asbestos']

# %% [markdown]
# #### How about retrieving a subset of data and not just individual data points?

# %% [markdown]
# #### Slice notation
#
# ![Screen Shot 2022-02-24 at 4.57.54 PM.png](data:image/png;base64,...)

# %%
## Call the first 3 items:

# %% [markdown]
# #### Slice notation
#
# ![Screen Shot 2022-02-24 at 5.01.32 PM.png](data:image/png;base64,...)

# %%
## Call the first 4 items:

# %% [markdown]
# ## Built-in Functions v. Python Methods
# You've encountered two built-in functions.
#
# ### Built-in functions

# %%
## print()

# %%
## type

# %% [markdown]
# In simplest terms (good for now), a ```built-in function``` comes as standard part of Python and carries out one or more steps on something we aim it at. What we target for the function goes inside the parenthesis:
#
# In the cases above, we asked to ```print(animals)``` or ```type(mixed_list)```.
#
# Will introduce others through the semester as need. There are <a href="https://docs.python.org/3/library/functions.html">dozens of built-in functions</a>, but I will be introducing the most useful ones little by little.

# %%
## how many items does an object hold?

# %% [markdown]
# ## Methods
#
# Python is an **object-oriented** language. Everything in Python is an object, like:
# - Integers
# - Float point numbers
# - Lists
# - Dictionaries
# - and many, many more
#
# Each object has one or more methods that do something specific to that object.
#
# **Hence the importance of always knowing what object you have on hand.**

# %% [markdown]
# ### List methods
#
# Methods nearly always appear in the following format:
#
# ```list_object.someMethod(some-data)```
#
# Let's look at one we encountered earlier:

# %%
## recall our of animals 
animals
# Out:
# ['dog', 'cat', 'pig', 'rat', 'hen']

# %%
## append an animal to our animals list
## append always adds it to the end
animals.append(mixed_list)

# %%
animals
# Out:
# ['dog',
#  'cat',
#  'pig',
#  'rat',
#  'hen',
#  ['dog',
#   2,
#   'pig',
#   ['frong', 'bird'],
#   'rat',
#   'hen',
#   True,
#   False,
#   'Sandeep',
#   [...]]]

# %% [markdown]
# For some methods, you don't need to add a value:

# %%
## reverse our animals list
animals.reverse()
animals
# Out:
# ['dog',
#  'cat',
#  'pig',
#  'rat',
#  'hen',
#  ['dog',
#   2,
#   'pig',
#   ['frong', 'bird'],
#   'rat',
#   'hen',
#   True,
#   False,
#   'Sandeep',
#   [...]]]

# %%
## What is the position of a certain value?
animals.index("rat")
# Out:
# 3

# %% [markdown]
# The first value in almost every programming language is ```zero-indexed```, or the count always starts at ```zero```.

# %%
## zero index animals

# %% [markdown]
# ## Sets
#
# A Python set is basically a list but with three major differences:
# 1. A set can only hold unique values. It can't hold duplicate values.
# 2. You can build a set using ```{}``` instead of ```[]```.
# 3. You create a set using the ```set()``` method

# %%
## Let's create a set
my_set = {5,12, 6, 9,5,12}
my_set
# Out:
# {5, 6, 9, 12}

# %% [markdown]
# A more realistic use is to take a list and to deduplicate it using the ```set()``` method.

# %%
## run this cell

# %%
## turn it into a set

# %%
## Actually save our mixed_vals_list into a variable

# %% [markdown]
# ### You can turn a set back into a list using the ```list()``` method

# %%
## convert it to a list here

# %% [markdown]
# ## Dictionaries
#
# A Python Dictionary is another common and powerful datatype.
#
# Think of it as a collection of data points about a single element.

# %% [markdown]
# For example, a car model:
#
# - Brand: Honda
# - Type: SUV
# - Model: CRV
# - Trim: Leather
# - cost: 40_000
# - on_sale: True
# - VIN: 2973

# %% [markdown]
# A dictionary would hold this data as **key: value** pairs
#
# A dictionary is wrapped in ```{}```.
#
# Each key: value pair is separated by a comma.
#
# The format is ```{"key1_string": "string_value", "key2_number": 12, "key3_bolean": True}```

# %%
## build the car_1 dictionary
car1= {"Brand": "Honda", 
        "Type": "SUV", 
        "Model": "CRV", 
        "Trim": "Leather", 
        "cost": 40_000, 
        "on_sale": True, 
        "VIN": 2973}
car1
# Out:
# {'Brand': 'Honda',
#  'Type': 'SUV',
#  'Model': 'CRV',
#  'Trim': 'Leather',
#  'cost': 40000,
#  'on_sale': True,
#  'VIN': 2973}

# %%
## call car_1

# %%
## what car_1's datatype
type(car1)
# Out:
# dict

# %% [markdown]
# Build me a dictionary called car_2 with the following data points.
#
# Note: In this case the vin is first. The order in a dictionary doesn't matter.
#
# - vin: 8303
# - Brand: Honda
# - Type: Sedan
# - Model: CRV
# - Trim: Cloth
# - cost: 35_000
# - on sale: no

# %%
## build car_2
car2= {"Brand": "Honda", 
        "Type": "Sedan", 
        "Model": "Accord", 
        "Trim": "Cloth", 
        "cost": 35_000, 
        "on_sale": False, 
        "VIN": 8303}
car2
# Out:
# {'Brand': 'Honda',
#  'Type': 'Sedan',
#  'Model': 'Accord',
#  'Trim': 'Cloth',
#  'cost': 35000,
#  'on_sale': False,
#  'VIN': 8303}

# %%
## call car_2
car2
# Out:
# {'Brand': 'Honda',
#  'Type': 'Sedan',
#  'Model': 'Accord',
#  'Trim': 'Cloth',
#  'cost': 35000,
#  'on_sale': False,
#  'VIN': 8303}

# %% [markdown]
# ## A create a list with these two dictionaries

# %%
## create a list called honda_cars here
cars = [car1,car2]

# %%
## call this list
cars
# Out:
# [{'Brand': 'Honda',
#   'Type': 'SUV',
#   'Model': 'CRV',
#   'Trim': 'Leather',
#   'cost': 40000,
#   'on_sale': True,
#   'VIN': 2973},
#  {'Brand': 'Honda',
#   'Type': 'Sedan',
#   'Model': 'Accord',
#   'Trim': 'Cloth',
#   'cost': 35000,
#   'on_sale': False,
#   'VIN': 8303}]

# %%
import pandas as pd

# %%
## export list of dictionaries
df = pd.DataFrame(cars)

# %%
df
# Out:
#    Brand   Type Model     Trim   cost  on_sale   VIN
# 0  Honda    SUV   CRV  Leather  40000     True  2973
# 1  Honda  Sedan   CRV    Cloth  35000    False  8303

# %%
df.to_csv("honda-scrape.csv", encoding = "UTF-8", index = False)

# %% [markdown]
# ## List of Dictionaries
#
# We come full circle. A list of dictionaries is equivalent to data in a CSV file. Here, I exported and opened this data in Excel:
#
# ![Screen%20Shot%202022-02-13%20at%2010.15.00%20AM.png](attachment:Screen%20Shot%202022-02-13%20at%2010.15.00%20AM.png)

# %% [markdown]
# ### What are relevant journalistic uses for the various datatypes and methods above?
#
# 1. Making numbers more readable (using f-string literal formatting)
# 2. Organizing data points after acquiring them through scraping (creating lists, dictionaries and lists of dictionaries)
# 3. Knowing what type of data (or Python object) we have.
# 4. Knowing how many such data points we have.
# 5. Confirming that we have unique values (or removing duplicates in a data set)
