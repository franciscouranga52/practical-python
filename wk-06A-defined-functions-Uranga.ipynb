# %% [markdown]
# # Functions
#
# The real power in any programming language is the **```Function```**.
#
# A **```Function```** is:
#
# * a little block of script (one line or many) that performs specific task or a series of tasks.
# * reusable and helps us make our code DRY.
# * triggered when something "invokes" or "calls" it.
# * ideally modular – it performs a narrow task and you call several functions to perform more complex tasks.

# %%
## "define" a function that says "Hello World"
def hello ():
    print("Hello world!")

# %%
## "invoke" or "call" the function
hello()
# Out:
# Hello world!

# %%
## Add parameter
def hello (name):
    print(f"Hello {name}. Hope you're having a nice day!")

# %%
## invoke and add value for parameter
hello("Sandeep")
# Out:
# Hello Sandeep. Hope you're having a nice day!

# %% [markdown]
# ## Build a function called ```addNumbers``` that adds 2 numbers together
# ## it should print "The total is (whatever the number is)!"

# %%
## build it here 
def addNumbers (number1,number2): #suele usar cammel case para funciones
    total = number1 + number2
    print(f"The total is {total}")

# %%
## Call myFunction using 4 and 5 as the arguments
addNumbers (4,5)
# Out:
# The total is 9

# %%
## Call myFunction using 10 and 2 as the arguments
addNumbers (10,2)
# Out:
# The total is 12

# %% [markdown]
# ## Parameters v. Arguments
# El parámetro es el genérico de la función (number1) y argumento es cuando es un valor (5, por ejemplo)

# %% [markdown]
# ### A function with parameters
#
# ![Screen Shot 2022-01-25 at 1.59.44 PM.png](data:image/png;base64,...)

# %% [markdown]
# ### Calling a function with arguments
#
# ![Screen Shot 2022-01-25 at 7.50.08 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## A **parameter** is what is declared in the function while an **argument** is what is *passed* through a function

# %%
## you might forget what arguments are needed for the function to work.
## you can add notes that appear on shift-tab as you call the function.
## write it here
def addNumbers (number1, number2):
    '''
    Needs 2 numbers as arguments
    adds them together and prints total
    name of csv as string with .csv extension
    ''' # esto agrega el docstring que te permite saber qué necesito poner en la función
    total = number1 + number2 
    print(f"The total is {total}")

# %%
## test it on 3 and 4
addNumbers()

# %% [markdown]
# ### To use or not use functions?
#
# Let's compare the two options with a simple example:

# %%
## You have a list of numbers.
mylist1 = [1, -5, 22, -44.2, 33, -45]

# %%
## Turn each number into an absolute number.
## a for loop works perfectly fine here.
## for loop for list 2
for number in mylist1:
    print(abs(number))
# Out:
# 1
# 5
# 22
# 44.2
# 33
# 45

# %%
## The problem is that your project keeps generating more lists.
## Each list of numbers has to be turned into absolute numbers
mylist2 = [-56, -34, -75, -111, -22]
mylist3 = [-100, -200, 100, -300, -100]
mylist4 = [-23, -89, -11, -45, -27]
mylist5 = [0, 1, 2, 3, 4, 5]

# %%
## for loop for list 2
for number in mylist2:
    print(abs(number))
# Out:
# 56
# 34
# 75
# 111
# 22

# %% [markdown]
# ## DRY
#
#
# ### Do you keep writing for loops for each list?
#
# ### No, that's a lot of repetition!
# ### DRY stands for "Don't Repeat Yourself"

# %%
## Instead we write a function that takes a list,
## converts each list item to an absolute number,
## and prints out the number
def absolutVals (list_name):
    '''
    takes a list of numbers and prints out their absolute values 
    '''
    for number in list_name:
        print(abs(number))

# %%
## Try swapping out different lists into the function:
absolutVals(mylist5)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
## try on list 2
absolutVals(mylist2)
# Out:
# 56
# 34
# 75
# 111
# 22

# %%
## try on list 4
absolutVals(mylist4)
# Out:
# 23
# 89
# 11
# 45
# 27

# %% [markdown]
# ## Timesaver
# ### Imagine for a moment that your editor tells you that the calculation needs to be updated. Instead of needing the absolute number, you need the absolute number minus 5.
#
# ### Having used multiple for loops, you'd have to change each one. What if you miss one or two? Either way, it's a chore.
#
# ### With functions, you just revise the function and the update runs everywhere.

# %%
## So if an editor says to actually multiply the absolute number by 1_000_000,

def absolutVals (list_name):
    '''
    takes a list of numbers and prints out their absolute values 
    and mutiply by 1000000
    '''
    for number in list_name:
        print(abs(number)*1000000)

# %%
## Try swapping out different lists into the function:
absolutVals(mylist2)
# Out:
# 56000000
# 34000000
# 75000000
# 111000000
# 22000000

# %% [markdown]
# ## Return Statements
#
# ### So far we have only printed out values processed by a function.
#
# ### But we really want to retain the value the function creates.
#
# ### We can then pass that value to other parts of our calculations and code.

# %%
## Simple example
## A function that adds two numbers together and prints the value:
addNumbers(10,20)
# Out:
# The total is 30

# %%
## let's try to save it in a variable called myCalc
my_result = addNumbers (10,20)
my_result
# Out:
# The total is 30

# %%
## Print myCalc. What does it hold?
my_result

# %%
## type of data calc?
type(my_result)
# Out:
# NoneType

# %% [markdown]
# ### The return Statement

# %%
## Tweak our function by adding return statement
## instead of printing a value we want to return a value(or values).

def addNumbers (number1, number2):
    '''
    needs 2 numbers as arguments 
    adds them together and returns total
    '''
    total = number1 + number2
    print(f"The total is {total}!")
    return total

# %%
## shorten our previous function
def addNumbers (number1, number2):
    '''
    needs 2 numbers as arguments 
    adds them together and returns total
    '''
    return number1 + number2

# %%
## call the function add_numbers_ret
## and store in variable called myCalc
my_result = addNumbers(1,2)

# %%
## print myCalc
my_result
# Out:
# 3

# %%
## What type is myCalc?
type(my_result)
# Out:
# int

# %% [markdown]
# ## Return multiple values

# %%
## demo function - take name (upper case it), age (subtrack 5), all cap country (title case it)
def getPerson (name, age, country):
    '''
    Acá va a la descripción
    '''
    return name.title(), age - 5, country.upper()

# %%
## call function here and sore into variables
getPerson("Mrinalini", 50, "India") #devuelve una tuple
# Out:
# ('Mrinalini', 45, 'INDIA')

# %%
# asignar a variables
name, age, country = getPerson("Mrinalini", 50, "India")

# %%
## call name
name
# Out:
# 'Mrinalini'

# %%
## call country
age
# Out:
# 45

# %%
## call age
country
# Out:
# 'INDIA'

# %%
## the order of the variables matter

# %% [markdown]
# ### Let's revise our earlier absolute values converter with a return statement
# #### Here is the earlier version:
#
# ![abs-function.png](data:image/png;base64,...)

# %%
## Let's revise our earlier aboslute_values with a return statement

def absoluteValues (listName):
    '''
    Takes a list, returnes an updated list of absolute values
    '''
    list_absolute = []
    for number in listName:
        list_absolute.append(abs(number))
    return list_absolute

# %%
mylist1
# Out:
# [1, -5, 22, -44.2, 33, -45]

# %%
## recall list 1
absoluteValues(mylist1)
# Out:
# [1, 5, 22, 44.2, 33, 45]

# %%
## Let's actually make that a list comprehension version of the function:
## Let's revise our earlier aboslute_values with a return statement

def absoluteValuesLc (listName):
    '''
    Takes a list, returnes an updated list of absolute values
    '''
    return [abs(number) for number in listName]
    return list_absolute

# %%
## Let's test it by storing the return value in variable x
my_calc_lc = absoluteValuesLc(mylist1)
my_calc_lc
# Out:
# [1, 5, 22, 44.2, 33, 45]

# %%
## What type of data object is it?
type(my_calc_lc)
# Out:
# list
